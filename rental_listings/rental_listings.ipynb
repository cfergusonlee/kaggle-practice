# %% [markdown]
# In this exploration notebook, we shall try to uncover the basic information about the dataset which will help us build our models / features.
#
# Let us first import the necessary modules.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# %matplotlib inline

#pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# Loading the training dataset and looking at the top few rows.

# %%
train_df = pd.read_json("data/train.json")
train_df.head()
# Out:
#         bathrooms  bedrooms                       building_id  \
# 10            1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 10000         1.0         2  c5c8a357cba207596b04d1afd1e4f130
# 100004        1.0         1  c3ba40552e2120b0acfc3cb5730bb2aa
# 100007        1.0         1  28d9ad350afeaab8027513a3e52ac8d5
# 100013        1.0         4                                 0
#
#                     created  \
# 10      2016-06-24 07:54:24
# 10000   2016-06-12 12:19:27
# 100004  2016-04-17 03:26:41
# 100007  2016-04-18 02:22:02
# 100013  2016-04-28 01:32:41
#
#                                               description  \
# 10      A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 10000
# 100004  Top Top West Village location, beautiful Pre-w...
# 100007  Building Amenities - Garage - Garden - fitness...
# 100013  Beautifully renovated 3 bedroom flex 4 bedroom...
#
#             display_address  \
# 10      Metropolitan Avenue
# 10000       Columbus Avenue
# 100004          W 13 Street
# 100007     East 49th Street
# 100013    West 143rd Street
#
#                                                  features interest_level  \
# 10                                                     []         medium
# 10000   [Doorman, Elevator, Fitness Center, Cats Allow...            low
# 100004  [Laundry In Building, Dishwasher, Hardwood Flo...           high
# 100007                          [Hardwood Floors, No Fee]            low
# 100013                                          [Pre-War]            low
#
#         latitude  listing_id  longitude                        manager_id  \
# 10       40.7145     7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 10000    40.7947     7150865   -73.9667  7533621a882f71e25173b27e3139d83d
# 100004   40.7388     6887163   -74.0018  d9039c43983f6e564b1482b273bd7b01
# 100007   40.7539     6888711   -73.9677  1067e078446a7897d2da493d2f741316
# 100013   40.8241     6934781   -73.9493  98e13ad4b495b9613cef886d79a6291f
#
#                                                    photos  price  \
# 10      [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 10000   [https://photos.renthop.com/2/7150865_be3306c5...   5465
# 100004  [https://photos.renthop.com/2/6887163_de85c427...   2850
# 100007  [https://photos.renthop.com/2/6888711_6e660cee...   3275
# 100013  [https://photos.renthop.com/2/6934781_1fa4b41a...   3350
#
#                  street_address
# 10      792 Metropolitan Avenue
# 10000       808 Columbus Avenue
# 100004          241 W 13 Street
# 100007     333 East 49th Street
# 100013    500 West 143rd Street

# %% [markdown]
# Wow. This dataset looks interesting. It has numerical features, categorical features, date feature, text features and image features.
#
# Let us load the test data as well and check the number of rows in train and test to start with.

# %%
test_df = pd.read_json("data/test.json")
print("Train Rows : ", train_df.shape[0])
print("Test Rows : ", test_df.shape[0])
# Out:
# ('Train Rows : ', 49352)
# ('Test Rows : ', 74659)

# %% [markdown]
# **Target Variable**
#
# Before delving more into the features, let us first have a look at the target variable 'interest level'

# %%
int_level = train_df['interest_level'].value_counts()

plt.figure(figsize=(12,8))
sns.barplot(int_level.index, int_level.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Interest level', fontsize=12)
plt.show()

# %% [markdown]
# Interest level is low for most of the cases followed by medium and then high which makes sense.
#
# Now let us start looking into the numerical features present in the dataset. Numerical features are
#
#  - bathrooms
#  - bedrooms
#  - price
#  - latitude
#  - longitude
#
# The last two are actually not numerical variables, but for now let us just consider it to be numerical.
#
# **Bathrooms:**
#
# Let us first start with bathrooms.

# %%
cnt_srs = train_df['bathrooms'].value_counts()

plt.figure(figsize=(12,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[0])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('bathrooms', fontsize=12)
plt.show()

# %%
#sns.reset_orig()
cnt_srs = train_df['bathrooms'].value_counts()
cnt_srs.sort_index(inplace=True)

plt.figure(figsize=(12,8))
plt.bar(range(len(cnt_srs.index)), cnt_srs.values, alpha=0.8, color=color[0])
for x, y in zip(range(len(cnt_srs.index)), cnt_srs.values):
    plt.text(x+0, y+3, y, ha="center", va="bottom")
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('bathrooms', fontsize=12)
plt.xticks(range(len(cnt_srs.index)), cnt_srs.index)
plt.show()

# %%
train_df.loc[train_df['bathrooms']>3,'bathrooms'] = 3
plt.figure(figsize=(12,8))
sns.violinplot(x='interest_level', y='bathrooms', data=train_df)
plt.xlabel('Interest level', fontsize=12)
plt.ylabel('bathrooms', fontsize=12)
plt.show()

# %% [markdown]
# Looks like evenly distributed across the interest levels. Now let us look at the next feature 'bedrooms'.
#
# **Bedrooms:**

# %%
cnt_srs = train_df['bedrooms'].value_counts()

plt.figure(figsize=(12,8))
plt.bar(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[2])
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('bedrooms', fontsize=12)
for x,y in zip(cnt_srs.index, cnt_srs.values):
    plt.text(x, y+.3, y, ha="center", va="bottom")
plt.xticks(cnt_srs.index)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='bedrooms', hue='interest_level', data=train_df)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Bedrooms', fontsize=12)
plt.show()

# %% [markdown]
# **Price:**
#
# Now let us look at the price variable distribution.

# %%
plt.figure(figsize=(12,8))
ax = plt.gca()
plt.scatter(range(train_df.shape[0]), np.sort(train_df.price.values))
plt.xlabel('Index', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.yscale('log')
plt.yticks([10**i for i in range(2,7)], [format(l, ',.0f') for l in [10**i for i in range(2,8)]])
#plt.ticklabel_format(useOffset=False)
plt.show()

# %% [markdown]
# What a weird dataset. The housing prices rande from \$43 to \$4,449,000, with only 6 houses above \$100,000. What is this, Detroit? I don't think I've ever seen a community with that many houses under 100K. Looks like there are some outliers in this feature. So let us remove them and then plot again.

# %%
print "min:", min(train_df.price.values)
print "max:", max(train_df.price)
print "Number of records:", len(train_df)
print "Prices above 1,000,000:", len(train_df[train_df.price>1000000])
print "Prices above 100,000:", len(train_df[train_df.price>100000])
print "Prices above 50,000:", len(train_df[train_df.price>50000])
# Out:
# min: 43
# max: 4490000
# Number of records: 49352
# Prices above 1,000,000: 4
# Prices above 100,000: 6
# Prices above 50,000: 16

# %%
ulimit = np.percentile(train_df.price.values, 99)
train_df.loc[train_df['price']>ulimit,"price"] = ulimit

plt.figure(figsize=(12,8))
sns.distplot(train_df.price.values, bins=50, kde=True)
plt.xlabel('Price', fontsize=12)
plt.show()

# %% [markdown]
# The distribution is right skewed as we can see.
#
# Now let us look at the latitude and longitude variables.
#
# **Latitude & Longitude:**

# %%
llimit = np.percentile(train_df.latitude.values, 1)
ulimit = np.percentile(train_df.latitude.values, 99)
train_df.loc[train_df['latitude']<llimit, 'latitude'] = llimit
train_df.loc[train_df['latitude']>ulimit, 'latitude'] = ulimit

plt.figure(figsize=(12,8))
sns.distplot(train_df.latitude.values, bins=50, kde=False)
plt.xlabel('latitude', fontsize=12)
plt.show()

# %% [markdown]
# So the latitude values are primarily between 40.6 and 40.9. Now let us look at the longitude values.

# %%
llimit = np.percentile(train_df.longitude.values, 1)
ulimit = np.percentile(train_df.longitude.values, 99)
train_df.loc[train_df['longitude']<llimit, 'longitude'] = llimit
train_df.loc[train_df['longitude']>ulimit, 'longitude'] = ulimit

plt.figure(figsize=(12,8))
sns.distplot(train_df.longitude.values, bins=50, kde=False)
plt.xlabel('longitude', fontsize=12)
plt.show()

# %% [markdown]
# The longitude values range between -73.8 and -74.02. So the data corresponds to the **New York City**.
#
# Now let us plot the same in a map. Thanks to this [kernel][1] by Dotman.
#
#
#   [1]: https://www.kaggle.com/dotman/d/fivethirtyeight/uber-pickups-in-new-york-city/data-exploration-and-visualization

# %%
from mpl_toolkits.basemap import Basemap
from matplotlib import cm

west, south, east, north = -74.02, 40.64, -73.85, 40.86

fig = plt.figure(figsize=(14,10))
ax = fig.add_subplot(111)
m = Basemap(projection='merc', llcrnrlat=south, urcrnrlat=north,
            llcrnrlon=west, urcrnrlon=east, lat_ts=south, resolution='i')
x, y = m(train_df['longitude'].values, train_df['latitude'].values)
m.hexbin(x, y, gridsize=200,
         bins='log', cmap=cm.YlOrRd_r);

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/PopGen/Async/__init__.py:17: BiopythonDeprecationWarning: Bio.PopGen.Async has been deprecated, and we intend to remove it in a future release of Biopython. If you would like to continue using it, please contact the Biopython developers via the mailing list.
#   " via the mailing list.", BiopythonDeprecationWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/PopGen/FDist/__init__.py:28: BiopythonDeprecationWarning: Bio.PopGen.FDist has been deprecated, and we intend to remove it in a future release of Biopython. If you would like to continue using it, please contact the Biopython developers via the mailing list.
#   " via the mailing list.", BiopythonDeprecationWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/PopGen/SimCoal/__init__.py:17: BiopythonDeprecationWarning: Bio.PopGen.SimCoal has been deprecated, and we intend to  remove it in a future release of Biopython. If you would like to continue using it, please contact the Biopython developers via the mailing list.
#   " via the mailing list.", BiopythonDeprecationWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/SearchIO/__init__.py:211: BiopythonExperimentalWarning: Bio.SearchIO is an experimental submodule which may undergo significant changes prior to its future official release.
#   BiopythonExperimentalWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/codonalign/__init__.py:31: BiopythonExperimentalWarning: Bio.codonalign is an experimental module which may undergo significant changes prior to its future official release.
#   BiopythonExperimentalWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/Bio/phenotype/__init__.py:102: BiopythonExperimentalWarning: Bio.phenotype is an experimental submodule which may undergo significant changes prior to its future official release.
#   BiopythonExperimentalWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The matplotlib.delaunay module was deprecated in version 1.4. Use matplotlib.tri.Triangulation instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/zmq/backend/cffi/__pycache__/_cffi_ext.c:212:10: fatal error: 'zmq.h' file not found
# #include <zmq.h>
#          ^~~~~~~
# 1 error generated.
# /Users/courtneyfergusonlee/anaconda/envs/DAND/lib/python2.7/site-packages/zmq/backend/cffi/__pycache__/_cffi_ext.c:212:10: fatal error: 'zmq.h' file not found
# #include <zmq.h>
#          ^~~~~~~
# 1 error generated.
# Audio_mac           _tkinter            htmlentitydefs      quandl
# BaseHTTPServer      _vendor             htmllib             quopri
# Bastion             _warnings           httplib             random
# Bio                 _weakref            ic                  re
# BioSQL              _weakrefset         icglue              readline
# CGIHTTPServer       _yaml               icopen              repr
# Canvas              abc                 idlelib             requests
# Carbon              aepack              idna                requests_oauthlib
# CodeWarrior         aetools             ihooks              resource
# ColorPicker         aetypes             imaplib             rexec
# ConfigParser        aifc                imghdr              rfc822
# Cookie              antigravity         imp                 rlcompleter
# Dialog              anydbm              importlib           rmagic
# DocXMLRPCServer     applesingle         imputil             robotparser
# EasyDialogs         appletrawmain       inflection          runpy
# Explorer            appletrunner        inspect             sched
# FileDialog          appnope             io                  scipy
# Finder              argparse            ipaddress           seaborn
# FixTk               argvemulator        ipykernel           select
# FrameWork           array               ipython_genutils    sets
# HTMLParser          asn1crypto          ipywidgets          setuptools
# IN                  ast                 itertools           sgmllib
# IPython             asynchat            jinja2              sha
# MacOS               asyncore            json                shapefile
# MimeWriter          atexit              jsonschema          shelve
# MiniAEFrame         audiodev            jupyter             shlex
# Nav                 audioop             jupyter_client      shutil
# Netscape            autoGIL             jupyter_console     signal
# OSATerminology      autoreload          jupyter_contrib_core simplegeneric
# OpenSSL             backports           jupyter_contrib_nbextensions singledispatch
# PixMapWrapper       backports_abc       jupyter_core        singledispatch_helpers
# PyQt5               base64              jupyter_highlight_selected_word sip
# Queue               bdb                 jupyter_nbextensions_configurator sipconfig
# ScrolledText        bgenlocations       keyword             sipdistutils
# SimpleDialog        binascii            latex_envs          site
# SimpleHTTPServer    binhex              lib2to3             six
# SimpleXMLRPCServer  binstar_client      linecache           sklearn
# SocketServer        bisect              locale              smtpd
# StdSuites           bs4                 logging             smtplib
# StringIO            bsddb               macerrors           sndhdr
# SystemEvents        bsddb185            macostools          socket
# Terminal            bson                macpath             sqlite3
# Tix                 buildtools          macresource         sre
# Tkconstants         bundlebuilder       macurl2path         sre_compile
# Tkdnd               bz2                 mailbox             sre_constants
# Tkinter             cPickle             mailcap             sre_parse
# UserDict            cProfile            markupbase          ssl
# UserList            cStringIO           markupsafe          stat
# UserString          calendar            marshal             statvfs
# _AE                 cffi                math                storemagic
# _AH                 cfmfile             matplotlib          string
# _App                cgi                 md5                 stringold
# _CF                 cgitb               mhlib               stringprep
# _CG                 chunk               mimetools           strop
# _CarbonEvt          clyent              mimetypes           struct
# _Cm                 cmath               mimify              subprocess
# _Ctl                cmd                 mistune             subprocess32
# _Dlg                code                mmap                sunau
# _Drag               codecs              modulefinder        sunaudio
# _Evt                codeop              more_itertools      symbol
# _File               collections         mpl_toolkits        sympyprinting
# _Fm                 colorsys            multifile           symtable
# _Folder             command             multiprocessing     sys
# _Help               commands            mutex               sysconfig
# _IBCarbon           compileall          nb_anacondacloud    syslog
# _Icn                compiler            nb_conda            tabnanny
# _LWPCookieJar       configparser        nb_conda_kernels    tarfile
# _Launch             contextlib          nbconvert           telnetlib
# _List               cookielib           nbformat            tempfile
# _Menu               copy                nbpresent           terminado
# _Mlte               copy_reg            netrc               terminalcommand
# _MozillaCookieJar   crypt               new                 termios
# _OSA                cryptography        nis                 test_path
# _Qd                 csv                 nltk                tests
# _Qdoffs             ctypes              nntplib             textwrap
# _Qt                 curses              notebook            this
# _Res                cycler              ntpath              thread
# _Scrap              cythonmagic         nturl2path          threading
# _Snd                datetime            numbers             time
# _TE                 dateutil            numpy               timeit
# _Win                dbhash              oauthlib            tkColorChooser
# __builtin__         dbm                 opcode              tkCommonDialog
# __future__          decimal             operator            tkFileDialog
# _abcoll             decorator           optparse            tkFont
# _ast                difflib             os                  tkMessageBox
# _bisect             dircache            os2emxpath          tkSimpleDialog
# _builtinSuites      dis                 pandas              toaiff
# _cffi_backend       distutils           parser              token
# _codecs             django              path                tokenize
# _codecs_cn          doctest             pathlib2            tornado
# _codecs_hk          dumbdbm             pdb                 trace
# _codecs_iso2022     dummy_thread        pexpect             traceback
# _codecs_jp          dummy_threading     pickle              traitlets
# _codecs_kr          easy_install        pickleshare         ttk
# _codecs_tw          email               pickletools         tty
# _collections        encodings           pimp                turtle
# _csv                entrypoints         pip                 twython
# _ctypes             enum                pipes               types
# _ctypes_test        errno               pkg_resources       unicodecsv
# _curses             exceptions          pkgutil             unicodedata
# _curses_panel       extern              platform            unittest
# _elementtree        fcntl               plistlib            urllib
# _functools          filecmp             popen2              urllib2
# _geoslib            fileinput           poplib              urlparse
# _hashlib            findertools         posix               user
# _heapq              fnmatch             posixfile           uu
# _hotshot            formatter           posixpath           uuid
# _io                 fpformat            pprint              videoreader
# _json               fractions           profile             warnings
# _locale             ftplib              prompt_toolkit      wave
# _lsprof             functools           pstats              wcwidth
# _multibytecodec     functools32         pty                 weakref
# _multiprocessing    future_builtins     ptyprocess          webbrowser
# _osx_support        gc                  pwd                 wheel
# _posixsubprocess    genericpath         py_compile          whichdb
# _pyio               gensuitemodule      pyasn1              widgetsnbextension
# _random             gestalt             pyclbr              wsgiref
# _scproxy            getopt              pycparser           xdrlib
# _socket             getpass             pydoc               xlrd
# _sqlite3            gettext             pydoc_data          xml
# _sre                glob                pyexpat             xmllib
# _ssl                gridfs              pygments            xmlrpclib
# _strptime           grp                 pylab               xxsubtype
# _struct             gzip                pymongo             yaml
# _symtable           hashlib             pyparsing           zipfile
# _sysconfigdata      heapq               pyproj              zipimport
# _testcapi           hmac                pytz                zlib
# _threading_local    hotshot             qtconsole           zmq
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose descriptions contain the word "spam".

# %% [markdown]
# **Created:**
#
# Now let us look at the date column 'created'

# %%
train_df["created"] = pd.to_datetime(train_df["created"])
train_df["date_created"] = train_df["created"].dt.date
cnt_srs = train_df['date_created'].value_counts()


plt.figure(figsize=(12,4))
ax = plt.subplot(111)
ax.bar(cnt_srs.index, cnt_srs.values, alpha=0.8)
ax.xaxis_date()
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# So we have data from April to June 2016 in our train set. Now let us look at the test set as well and see if they are also from the same date range.

# %%
test_df["created"] = pd.to_datetime(test_df["created"])
test_df["date_created"] = test_df["created"].dt.date
cnt_srs = test_df['date_created'].value_counts()

plt.figure(figsize=(12,4))
ax = plt.subplot(111)
ax.bar(cnt_srs.index, cnt_srs.values, alpha=0.8)
ax.xaxis_date()
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Looks very similar to the train set dates and so we are good to go.!
#
# We shall also look at the hour-wise listing trend (Just for fun)

# %%
train_df["hour_created"] = train_df["created"].dt.hour
cnt_srs = train_df['hour_created'].value_counts()

plt.figure(figsize=(12,6))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[3])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Looks like listings are created during the early hours of the day (1 to 7am). May be that is when the traffic is less and so the updates are happening.
#
# Now let us look at some of the categorical variables.
#
# **Display Address:**

# %%
cnt_srs = train_df.groupby('display_address')['display_address'].count()

for i in [2, 10, 50, 100, 500]:
    print('Display_address that appear less than {} times: {}%'.format(i, round((cnt_srs < i).mean() * 100, 2)))

plt.figure(figsize=(12, 6))
plt.hist(cnt_srs.values, bins=100, log=True, alpha=0.9)
plt.xlabel('Number of times display_address appeared', fontsize=12)
plt.ylabel('log(Count)', fontsize=12)
plt.show()

# %% [markdown]
# Most of the display addresses occur less than 100 times in the given dataset. None of the display address occur more than 500 times.
#
# **Number of Photos:**
#
# This competition also has a huge database of photos of the listings. To start with, let us look at the number of photos given for listings.

# %%
train_df["num_photos"] = train_df["photos"].apply(len)
cnt_srs = train_df['num_photos'].value_counts()

plt.figure(figsize=(12,6))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.xlabel('Number of Photos', fontsize=12)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.show()

# %%
train_df['num_photos'].ix[train_df['num_photos']>12] = 12
plt.figure(figsize=(12,6))
sns.violinplot(x="num_photos", y="interest_level", data=train_df, order =['low','medium','high'])
plt.xlabel('Number of Photos', fontsize=12)
plt.ylabel('Interest Level', fontsize=12)
plt.show()

# %% [markdown]
# Let us now look at the number of features variable and see its distribution.
#
# **Number of features:**

# %%
train_df["num_features"] = train_df["features"].apply(len)
cnt_srs = train_df['num_features'].value_counts()

plt.figure(figsize=(12,6))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Number of features', fontsize=12)
plt.show()

# %%
train_df['num_features'].ix[train_df['num_features']>17] = 17
plt.figure(figsize=(12,10))
sns.violinplot(y="num_features", x="interest_level", data=train_df, order =['low','medium','high'])
plt.xlabel('Interest Level', fontsize=12)
plt.ylabel('Number of features', fontsize=12)
plt.show()

# %% [markdown]
# **Word Clouds:**
#
# Next we shall look into some for the text features.

# %%
from wordcloud import WordCloud

text = ''
text_da = ''
text_desc = ''
for ind, row in train_df.iterrows():
    for feature in row['features']:
        text = " ".join([text, "_".join(feature.strip().split(" "))])
    text_da = " ".join([text_da,"_".join(row['display_address'].strip().split(" "))])
    #text_desc = " ".join([text_desc, row['description']])
text = text.strip()
text_da = text_da.strip()
text_desc = text_desc.strip()

plt.figure(figsize=(12,6))
wordcloud = WordCloud(background_color='white', width=600, height=300, max_font_size=50, max_words=40).generate(text)
wordcloud.recolor(random_state=0)
plt.imshow(wordcloud)
plt.title("Wordcloud for features", fontsize=30)
plt.axis("off")
plt.show()

# wordcloud for display address
plt.figure(figsize=(12,6))
wordcloud = WordCloud(background_color='white', width=600, height=300, max_font_size=50, max_words=40).generate(text_da)
wordcloud.recolor(random_state=0)
plt.imshow(wordcloud)
plt.title("Wordcloud for Display Address", fontsize=30)
plt.axis("off")
plt.show()

# %% [markdown]
# **More to come. Stay tuned.!**
#
# Please upvote if you like the notebook :)
